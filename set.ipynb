# %%
#union
a={1,2,3,4,5}
b={4,6,7,8,9}
print(a.union(b))
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
# intersection
print(a.intersection(b))
# Out:
# {4}

# %%
#difference
print(a.difference(b))
# Out:
# {1, 2, 3, 5}

# %% [markdown]
# # add

# %%
numbers = {10, 2, 3, 3, 4}
print(numbers)
# Out:
# {2, 10, 3, 4}

# %%
a=numbers.add(5)
print(numbers)
# Out:
# {2, 3, 4, 5, 10}

# %% [markdown]
# # remove

# %%
numbers.remove(2)
print(numbers)
# Out:
# {3, 4, 5, 10}

# %% [markdown]
# # discard

# %%
numbers.discard(10)
print(numbers)
# Out:
# {3, 4, 5}

# %% [markdown]
# # pop()

# %%
numbers.pop()
# print(numbers)
# Out:
# 4

# %% [markdown]
# # clear

# %%
numbers.clear()
print(numbers)
# Out:
# set()
