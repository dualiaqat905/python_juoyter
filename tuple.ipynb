# %% [markdown]
# # Tuple

# %%
point = (10, 20)
print(point[0])
# Out:
# 10

# %% [markdown]
# # single element tuple

# %%
t = (5,)

# %% [markdown]
# # tuple packing and unpacking

# %%
data = (1, 2, 3)

a, b, c = data

print(a, b, c)
# Out:
# 1 2 3

# %% [markdown]
# # count

# %%
t=(1,2,"dua",False,2,2,2,5,5,"dua","dua","dua")
t.count(5)
# Out:
# 2

# %% [markdown]
# # index

# %%
t = (10, 20, 30, 20)

print(t.index(20))
# Out:
# 1

# %%
t = (5, 10, 5, 20, 5)

print(t.count(5))   # 3
print(t.index(10))  # 1
print(len(t))       # 5
print(20 in t)
# Out:
# 3
# 1
# 5
# True
