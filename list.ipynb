# %% [markdown]
# # list

# %%
a=[1,2.3,"dua",False]
print(a[1])
print(a[-2])
# Out:
# 2.3
# dua

# %%
print(a[1:3]) #3 wali count nai hogi 
print(a[-3:-1])
# Out:
# [2.3, 'dua']
# [2.3, 'dua']

# %%
a[2]="malika"
print(a)
# Out:
# [1, 2.3, 'malika', False]

# %% [markdown]
# # append

# %%
a.append(30)
print(a)
# Out:
# [1, 2.3, 'malika', False, 30]

# %% [markdown]
# # insert

# %%
a=[1,2.3,"dua",False]
a.insert(2,"malika")
print(a)
# Out:
# [1, 2.3, 'malika', 'dua', False]

# %% [markdown]
# # remove

# %%
a.remove("malika")
print(a)
# Out:
# [1, 2.3, 'dua', False]

# %% [markdown]
# # pop

# %%
a=[1,2.3,"dua",False]
a.pop(1)
# Out:
# 2.3

# %%
len(a)
# Out:
# 3

# %%
a=[1,2,3,4,5]
a.sort()
print(a)
# Out:
# [1, 2, 3, 4, 5]
